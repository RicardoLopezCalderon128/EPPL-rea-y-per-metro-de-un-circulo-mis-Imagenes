# %% [markdown]
# <a href="https://colab.research.google.com/github/RicardoLopezCalderon128/EPPL-rea-y-per-metro-de-un-circulo-mis-Imagenes/blob/main/El_profe_circulo_profe_Lopez_Ricardo_0085.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Ricardo Lopez NL = 29  25/Mar/2026 ⚡
# ---
# ### calcular area y perimetro
# ![logo de markdown](https://raw.githubusercontent.com/RicardoLopezCalderon128/EPPL-rea-y-per-metro-de-un-circulo-mis-Imagenes/refs/heads/main/Circulo_Area_perimetro.JPG)
#
# ---
# #### formula para calcular el area
# $=A=\pi*r^2$
#
# ---
# ### formula para calcular perimetro
# $P=2*\pi*r$
# ---
# ### Datos de entrada
# $r$ ?
# ---
# ###  diagrama de flujo de lucidchart
# ![logo de markdown](https://raw.githubusercontent.com/RicardoLopezCalderon128/EPPL-rea-y-per-metro-de-un-circulo-mis-Imagenes/refs/heads/main/DF%20Area%20perimetro%20circulo.png)
# ---

# %%
import math
# calcular area y perimetro de un circulo
# variables P, A, r
# Formulas A = pi*r^2 y P = 2 * pi * r
# capturar el valor de r
print("calcular area y perimetro de un circulo")
r=float(input("ingrese el valor del radio: "))
A = math.pi*r**2
P = 2*math.pi*r
print("el area del circulo es: ", A)
print("el perimetro del circulo es: ", P)
print("Lopez Ricardo NL = 29 ")
# Out:
# calcular area y perimetro de un circulo
# ingrese el valor del radio: 20
# el area del circulo es:  1256.6370614359173
# el perimetro del circulo es:  125.66370614359172
# Lopez Ricardo NL = 29

# %% [markdown]
# # Relacion entre codigo y DF en tldraw
# ![logo de markdown](https://raw.githubusercontent.com/RicardoLopezCalderon128/EPPL-rea-y-per-metro-de-un-circulo-mis-Imagenes/refs/heads/main/Tldraw%20DF%20y%20codigo.png)
