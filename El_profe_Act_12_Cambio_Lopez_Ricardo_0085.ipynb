# %% [markdown]
# <a href="https://colab.research.google.com/github/RicardoLopezCalderon128/EPPL-rea-y-per-metro-de-un-circulo-mis-Imagenes/blob/main/El_profe_Act_12_Cambio_Lopez_Ricardo_0085.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Ricardo Lopez NL = 29 Fecha 26/Mar/2026
# #### Calculando el cambio usando if else
# #### mirar diagrama de flujo
# ## las variables
# 1. CP -->  costo del producto
# 2. CD --> Cantidad de dinero
# 3. cambio
#
# ## Las formulas
# $Cambio = CD - CP$
#
#
# <img src="https://raw.githubusercontent.com/RicardoLopezCalderon128/calcular-cambio-if-else/refs/heads/main/Cambio.jfif" width= "300"  height="300" />
#
#
#
# ### diagrama de flujo lucicdhart
# <img src="https://raw.githubusercontent.com/RicardoLopezCalderon128/calcular-cambio-if-else/refs/heads/main/Diagrama%20de%20flujo%20if%20else%202.png" width= "400"  height="500" />

# %%
# para cuando es falso(no)
# calculando el cambio usando if else
# datos de entrada CD,CP
# mostrar cambio si es falso
# si es verdadero mostrar No alcanza
CP = float(input("ingrese el costo del producto: "))
CD = float(input("ingrese la cantidad de dinero: "))
if CP > CD:
  print("No alcanza")
else:
  cambio = CD - CP
  print("el cambio es: ",cambio)
print("fin del programa")
print("programa realizado por Lopez Ricardo NL = 29")
# Out:
# ingrese el costo del producto: 300
# ingrese la cantidad de dinero: 400
# el cambio es:  100.0
# fin del programa
# programa realizado por Lopez Ricardo NL = 29

# %% [markdown]
# ## codigo Relacion entre codigo y diagrama de flujo
#
# <img src="https://raw.githubusercontent.com/RicardoLopezCalderon128/calcular-cambio-if-else/refs/heads/main/Sin%20t%C3%ADtulo.png" width= "1000"  height="300" />
