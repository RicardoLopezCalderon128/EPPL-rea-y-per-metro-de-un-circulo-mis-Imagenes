# %% [markdown]
# <a href="https://colab.research.google.com/github/RicardoLopezCalderon128/EPPL-rea-y-per-metro-de-un-circulo-mis-Imagenes/blob/main/El_profe_circulo_profe_Lopez_Ricardo_0085.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Ricardo Lopez NL = 29  25/Mar/2026 ⚡
# ---
# ### calcular area de un triangulo
# ![logo de markdown](https://s5.static.brasilescola.uol.com.br/be/2022/07/area-do-triangulo.jpg)
#
# ---
# #### formula para calcular el area
# $=A=B*A/2$
#
# ---
#
# ---
# ### Datos de entrada
# $B, H$ ?
# ---
# ###  diagrama de flujo de lucidchart
# ![logo de markdown](https://raw.githubusercontent.com/RicardoLopezCalderon128/EPPL-rea-y-per-metro-de-un-circulo-mis-Imagenes/refs/heads/main/Diagrama%20en%20blanco.png)
# ---

# %%
import math
# calcular area de un triangulo
# variables b, h, A
# Formula A = (b * h) / 2
# capturar los valores de b y h
print("calcular area de un triangulo")
b = float(input("ingrese el valor de la base: "))
h = float(input("ingrese el valor de la altura: "))
A = (b * h) / 2
print("el area del triangulo es: ", A)
print("Lopez Ricardo NL = 29 ")
# Out:
# calcular area de un triangulo
# ingrese el valor de la base: 20
# ingrese el valor de la altura: 12
# el area del triangulo es:  120.0
# Lopez Ricardo NL = 29

# %% [markdown]
# # Relacion entre codigo y DF en tldraw
# ![logo de markdown](https://raw.githubusercontent.com/RicardoLopezCalderon128/EPPL-rea-y-per-metro-de-un-circulo-mis-Imagenes/refs/heads/main/diagrama%20de%20flujo%20area%20triangulo.png)
